# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/experimental/edmund_71Gpa_run1.csv')
# Out:
#            time        temp       oside
# 0  3.566200e-07  1941.51992  1975.32261
# 1  3.922800e-07  1942.59722  1979.94677
# 2  4.279400e-07  1946.87579  1981.57136
# 3  4.636000e-07  1942.45769  1974.38276
# 4  4.992600e-07  1940.40743  1971.73288

# %%
df['temp'].max()
# Out:
# np.float64(2050.66706)

# %%
fig, ax = plt.subplots()
ax.plot(df['time'], df['temp'], color='blue', label='pside')
ax.plot(df['time'], df['oside'], color='red', label='oside')
ax.legend()
